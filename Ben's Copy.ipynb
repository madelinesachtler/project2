# %%
import pandas as pd 
import pymongo
import os

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

db = client.project2

# %%
csvpath = "Resources/food_data2.csv"
food2_data = pd.read_csv(csvpath, encoding= 'unicode_escape')
food2_data.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.) Pop. Density (per sq. mi.) Coastline (coast/area ratio)  \
# 0          647500                       48,0                         0,00
# 1           28748                      124,6                         1,26
# 2         2381740                       13,8                         0,04
# 3             199                      290,4                        58,29
# 4             468                      152,1                         0,00
#
#   Net migration Infant mortality (per 1000 births)  GDP ($ per capita)  \
# 0         23,06                             163,07               700.0
# 1         -4,93                              21,52              4500.0
# 2         -0,39                                 31              6000.0
# 3        -20,71                               9,27              8000.0
# 4           6,6                               4,05             19000.0
#
#   Literacy (%) Phones (per 1000) Arable (%) Crops (%) Other (%) Climate  \
# 0         36,0               3,2      12,13      0,22     87,65       1
# 1         86,5              71,2      21,09      4,42     74,49       3
# 2         70,0              78,1       3,22      0,25     96,53       1
# 3         97,0             259,5         10        15        75       2
# 4        100,0             497,2       2,22         0     97,78       3
#
#   Birthrate Deathrate Agriculture Industry Service
# 0      46,6     20,34        0,38     0,24    0,38
# 1     15,11      5,22       0,232    0,188   0,579
# 2     17,14      4,61       0,101      0,6   0,298
# 3     22,46      3,27         NaN      NaN     NaN
# 4      8,71      6,25         NaN      NaN     NaN

# %%
food2_data = food2_data.dropna(how='any')

# %%
food2_data.count()
# Out:
# Country                               179
# Region                                179
# Population                            179
# Area (sq. mi.)                        179
# Pop. Density (per sq. mi.)            179
# Coastline (coast/area ratio)          179
# Net migration                         179
# Infant mortality (per 1000 births)    179
# GDP ($ per capita)                    179
# Literacy (%)                          179
# Phones (per 1000)                     179
# Arable (%)                            179
# Crops (%)                             179
# Other (%)                             179
# Climate                               179
# Birthrate                             179
# Deathrate                             179
# Agriculture                           179
# Industry                              179
# Service                               179
# dtype: int64

# %%
csvpath5 = "Resources/happiness_data/2019.csv"

happiness_2019 = pd.read_csv(csvpath5, encoding= 'unicode_escape')

# %%
happiness = happiness_2019.rename(columns={"Country or region": "Country"})
happiness.head()
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.769           1.340           1.587
# 1             2      Denmark  7.600           1.383           1.573
# 2             3       Norway  7.554           1.488           1.582
# 3             4      Iceland  7.494           1.380           1.624
# 4             5  Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298

# %%
csvpath6 = "Resources/freedom.csv"
freedom = pd.read_csv(csvpath6, encoding= 'unicode_escape')

# %%
#cleaning columns and renaming the to the primary key ("Country")
freedom = freedom.dropna(how='any')
freedom = freedom.rename(columns={"Country Name": "Country"})

# %%
freedom.count()
# Out:
# CountryID                      173
# Country                        173
# WEBNAME                        173
# Region                         173
# World Rank                     173
# Region Rank                    173
# 2019 Score                     173
# Property Rights                173
# Judical Effectiveness          173
# Government Integrity           173
# Tax Burden                     173
# Gov't Spending                 173
# Fiscal Health                  173
# Business Freedom               173
# Labor Freedom                  173
# Monetary Freedom               173
# Trade Freedom                  173
# Investment Freedom             173
# Financial Freedom              173
# Tariff Rate (%)                173
# Income Tax Rate (%)            173
# Corporate Tax Rate (%)         173
# Tax Burden % of GDP            173
# Gov't Expenditure % of GDP     173
# Country                        173
# Population (Millions)          173
# GDP (Billions, PPP)            173
# GDP Growth Rate (%)            173
# 5 Year GDP Growth Rate (%)     173
# GDP per Capita (PPP)           173
# Unemployment (%)               173
# Inflation (%)                  173
# FDI Inflow (Millions)          173
# Public Debt (% of GDP)         173
# dtype: int64

# %%
freedom.head(40)
freedom_new = freedom[["CountryID", "Country", "World Rank"]]
freedom_new
# Out:
#      CountryID      Country      Country  World Rank
# 0            1  Afghanistan  Afghanistan       152.0
# 1            2      Albania      Albania        52.0
# 2            3      Algeria      Algeria       171.0
# 3            4       Angola       Angola       156.0
# 4            5    Argentina    Argentina       148.0
# ..         ...          ...          ...         ...
# 180        178      Vanuatu      Vanuatu       116.0
# 181        179    Venezuela    Venezuela       179.0
# 182        180      Vietnam      Vietnam       128.0
# 184        182       Zambia       Zambia       138.0
# 185        183     Zimbabwe     Zimbabwe       175.0
#
# [173 rows x 4 columns]

# %%
#only the first 4 columns 
food_data3 = food2_data[["Country", "Region", "Population", "Area (sq. mi.)"]]
food_data3
# Out:
#                 Country                               Region  Population  \
# 0          Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1              Albania   EASTERN EUROPE                          3581655
# 2              Algeria   NORTHERN AFRICA                        32930091
# 6             Anguilla               LATIN AMER. & CARIB           13477
# 7    Antigua & Barbuda               LATIN AMER. & CARIB           69108
# ..                  ...                                  ...         ...
# 218          Venezuela               LATIN AMER. & CARIB        25730435
# 219            Vietnam         ASIA (EX. NEAR EAST)             84402966
# 224              Yemen   NEAR EAST                              21456188
# 225             Zambia   SUB-SAHARAN AFRICA                     11502010
# 226           Zimbabwe   SUB-SAHARAN AFRICA                     12236805
#
#      Area (sq. mi.)
# 0            647500
# 1             28748
# 2           2381740
# 6               102
# 7               443
# ..              ...
# 218          912050
# 219          329560
# 224          527970
# 225          752614
# 226          390580
#
# [179 rows x 4 columns]

# %%
#country, rank, gdp and freedom to make life choices 
happiness.head()
# Out:
#    Overall rank      Country  Score  GDP per capita  Social support  \
# 0             1      Finland  7.769           1.340           1.587
# 1             2      Denmark  7.600           1.383           1.573
# 2             3       Norway  7.554           1.488           1.582
# 3             4      Iceland  7.494           1.380           1.624
# 4             5  Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# 2                      0.341
# 3                      0.118
# 4                      0.298
